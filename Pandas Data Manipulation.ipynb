# %%
import pandas as pd
import numpy as np

# %%
performance = pd.read_csv('StudentsPerformance.csv')
performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # EDA

# %%
performance.shape
# Out:
# (1000, 8)

# %%
performance.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# # Sorting Datarames

# %%
# using the pandas dataframe method: pd.sort_values()
performance.sort_values('parental level of education')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 669    male        group D          associate's degree      standard
# 457    male        group D          associate's degree  free/reduced
# 454  female        group C          associate's degree  free/reduced
# 452  female        group C          associate's degree  free/reduced
# 173  female        group C          associate's degree      standard
# ..      ...            ...                         ...           ...
# 513  female        group B            some high school      standard
# 515  female        group C            some high school      standard
# 265    male        group D            some high school  free/reduced
# 853    male        group E            some high school      standard
# 336    male        group D            some high school      standard
#
#     test preparation course  math score  reading score  writing score
# 669               completed          81             72             77
# 457                    none          53             54             48
# 454                    none          53             61             62
# 452                    none          65             77             74
# 173                    none          63             67             70
# ..                      ...         ...            ...            ...
# 513               completed          54             61             62
# 515               completed          76             87             85
# 265                    none          59             42             41
# 853                    none          82             67             61
# 336               completed          76             70             69
#
# [1000 rows x 8 columns]

# %%
performance.sort_values('parental level of education', ascending= False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 546  female        group A            some high school      standard
# 265    male        group D            some high school  free/reduced
# 223    male        group D            some high school      standard
# 222  female        group C            some high school  free/reduced
# 722  female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 606  female        group C          associate's degree      standard
# 310  female        group B          associate's degree      standard
# 826  female        group C          associate's degree  free/reduced
# 313  female        group C          associate's degree  free/reduced
# 719    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 546               completed          92            100             97
# 265                    none          59             42             41
# 223                    none          86             80             75
# 222                    none          55             65             62
# 722               completed          74             90             88
# ..                      ...         ...            ...            ...
# 606                    none          85             84             82
# 310                    none          73             76             80
# 826               completed          56             68             70
# 313               completed          68             67             69
# 719               completed          91             73             80
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## sorting by multiple variables

# %%
performance.sort_values(['race/ethnicity','parental level of education','test preparation course'])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 46   female        group A          associate's degree      standard
# 489    male        group A          associate's degree  free/reduced
# 539    male        group A          associate's degree      standard
# 575    male        group A          associate's degree  free/reduced
# 653  female        group A          associate's degree      standard
# ..      ...            ...                         ...           ...
# 581  female        group E            some high school      standard
# 786  female        group E            some high school  free/reduced
# 853    male        group E            some high school      standard
# 895  female        group E            some high school  free/reduced
# 952  female        group E            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 46                completed          55             65             62
# 489               completed          79             82             82
# 539               completed          97             92             86
# 575               completed          40             55             53
# 653               completed          65             70             74
# ..                      ...         ...            ...            ...
# 581                    none          77             79             80
# 786                    none          72             79             77
# 853                    none          82             67             61
# 895                    none          32             34             38
# 952                    none          74             74             72
#
# [1000 rows x 8 columns]

# %%
performance.sort_values(['race/ethnicity','parental level of education','test preparation course'], ascending=[False,False,True])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 289    male        group E            some high school      standard
# 390    male        group E            some high school  free/reduced
# 545    male        group E            some high school  free/reduced
# 711  female        group E            some high school      standard
# 727    male        group E            some high school      standard
# ..      ...            ...                         ...           ...
# 356    male        group A          associate's degree      standard
# 490  female        group A          associate's degree  free/reduced
# 614  female        group A          associate's degree      standard
# 741  female        group A          associate's degree  free/reduced
# 936    male        group A          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 289               completed          77             76             77
# 390               completed          73             67             59
# 545               completed          78             83             80
# 711               completed          80             85             85
# 727               completed          68             51             57
# ..                      ...         ...            ...            ...
# 356                    none          63             61             61
# 490                    none          65             85             76
# 614                    none          82             93             93
# 741                    none          37             57             56
# 936                    none          67             57             53
#
# [1000 rows x 8 columns]

# %% [markdown]
# # Subsetting dataframes

# %% [markdown]
# ### subsettting by columns

# %%
performance['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
performance[['gender','lunch','math score']]
# Out:
#      gender         lunch  math score
# 0    female      standard          72
# 1    female      standard          69
# 2    female      standard          90
# 3      male  free/reduced          47
# 4      male      standard          76
# ..      ...           ...         ...
# 995  female      standard          88
# 996    male  free/reduced          62
# 997  female  free/reduced          59
# 998  female      standard          68
# 999  female  free/reduced          77
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### subsetting rows

# %%
# subsetting rows with logical conditions

# %%
performance[performance['lunch'] == 'standard']
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 5    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 994    male        group A                 high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 4                      none          76             78             75
# 5                      none          71             83             78
# ..                      ...         ...            ...            ...
# 987               completed          81             75             76
# 991               completed          65             82             78
# 994                    none          63             63             62
# 995               completed          88             99             95
# 998               completed          68             78             77
#
# [645 rows x 8 columns]

# %%
#subsetting with multiple condition
performance[(performance['math score'] > 80) & (performance['test preparation course'] == 'completed')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 6    female        group B                some college      standard
# 35     male        group E          associate's degree      standard
# 49     male        group C                 high school      standard
# 56   female        group E          associate's degree      standard
# 104    male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 934    male        group C          associate's degree      standard
# 938    male        group D                some college      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 6                 completed          88             95             92
# 35                completed          81             81             79
# 49                completed          82             84             82
# 56                completed          82             85             86
# 104               completed          98             86             90
# ..                      ...         ...            ...            ...
# 934               completed          98             87             90
# 938               completed          85             81             85
# 987               completed          81             75             76
# 990               completed          86             81             75
# 995               completed          88             99             95
#
# [84 rows x 8 columns]

# %% [markdown]
# # ADDING NEW COLUMNS

# %% [markdown]
# #### adding new columns with existing column

# %%
performance['total scores'] = performance['math score'] + performance['reading score'] + performance['writing score']

# %%
performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      total scores
# 0             218
# 1             247
# 2             278
# 3             148
# 4             229
# ..            ...
# 995           282
# 996           172
# 997           195
# 998           223
# 999           249
#
# [1000 rows x 9 columns]

# %% [markdown]
# # Grouped summary statistics

# %%
performance.groupby('parental level of education')['gender'].value_counts()
# Out:
# parental level of education  gender
# associate's degree           female    116
#                              male      106
# bachelor's degree            female     63
#                              male       55
# high school                  male      102
#                              female     94
# master's degree              female     36
#                              male       23
# some college                 female    118
#                              male      108
# some high school             female     91
#                              male       88
# Name: gender, dtype: int64

# %%
performance.groupby(['test preparation course','gender'])[['math score','reading score']].mean()
# Out:
#                                 math score  reading score
# test preparation course gender
# completed               female   67.195652      77.375000
#                         male     72.339080      70.212644
# none                    female   61.670659      69.982036
#                         male     66.688312      62.795455

# %%
performance.groupby(['gender','race/ethnicity'])[['math score','reading score', 'writing score']].agg([np.min,np.max,np.mean,np.median])
# Out:
#                       math score                        reading score       \
#                             amin amax       mean median          amin amax
# gender race/ethnicity
# female group A                34   92  58.527778     57            43  100
#        group B                 8   97  61.403846     62            24   97
#        group C                 0   96  62.033333     63            17  100
#        group D                26   98  65.248062     65            31  100
#        group E                32  100  70.811594     71            34  100
# male   group A                28  100  63.735849     63            23   96
#        group B                30   94  65.930233     65            24   96
#        group C                27   98  67.611511     68            28  100
#        group D                39  100  69.413534     71            34   97
#        group E                30  100  76.746479     78            26  100
#
#                                         writing score
#                             mean median          amin amax       mean median
# gender race/ethnicity
# female group A         69.000000   67.5            41   97  67.861111   67.0
#        group B         71.076923   71.5            23   96  70.048077   71.5
#        group C         71.944444   73.0            10  100  71.777778   74.0
#        group D         74.046512   74.0            32  100  75.023256   76.0
#        group E         75.840580   76.0            38  100  75.536232   76.0
# male   group A         61.735849   61.0            19   92  59.150943   60.0
#        group B         62.848837   62.0            15   92  60.220930   60.0
#        group C         65.424460   66.0            27   95  62.712230   62.0
#        group D         66.135338   68.0            34   99  65.413534   67.0
#        group E         70.295775   73.0            22  100  67.394366   70.0
